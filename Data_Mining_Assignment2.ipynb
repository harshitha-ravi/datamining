# %%
# Import statements
import pandas as pd
import numpy as np
from collections import Counter
from functools import reduce

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess

# %%
# stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words  = stopwords.words("english")
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Read the data file
df = pd.read_csv("train_data.csv")

# %%
# I'm considering only 8000 rows from the entire dataset - to implement Naive Bayes
# Because - my notebook is crashing for huge data

df = df[:8000]
df
# Out:
#       Unnamed: 0  Sentence_id  \
# 0              0  GERRES15609
# 1              1  PHERES15784
# 2              2  GERREQ10457
# 3              3  GERSKL27235
# 4              4  HONSSK18415
# ...          ...          ...
# 7995        7995   HONSKL1751
# 7996        7996  UAESSK42241
# 7997        7997  GERREQ10410
# 7998        7998  COGRES47805
# 7999        7999  GERSSK21464
#
#                                            New_Sentence            Type
# 0     Author and/or Review architecture/design and o...  Responsibility
# 1     Should be able to develop custom dynamic shape...  Responsibility
# 2     Experience in working crosslly with a  larger ...     Requirement
# 3     Previous business experience, including but no...           Skill
# 4            Delivering fast and right the first  time.       SoftSkill
# ...                                                 ...             ...
# 7995                  Sr  Director Customer Experience.           Skill
# 7996                     Excellent analytical  skills .       SoftSkill
# 7997         Strong experience in integration  testing.     Requirement
# 7998  Optimize the sales organization and processes,...  Responsibility
# 7999  Detail-oriented, organized,  and able to deliv...       SoftSkill
#
# [8000 rows x 4 columns]

# %%
# Divide the data into train, dev and test
# We will shuffle the whole dataset first (df.sample(frac=1, random_state=42)),
# and then split our data set into the following parts
# Train - 80%, Dev - 10%, Test - 10%

train, dev, test = np.split(df.sample(frac=1, random_state=42), 
                       [int(.8*len(df)), int(.9*len(df))])

# %%
# shape of train data
train.shape
# Out:
# (6400, 4)

# %%
# shape of dev data
dev.shape
# Out:
# (800, 4)

# %%
# shape of test data
test.shape
# Out:
# (800, 4)

# %%
train
# Out:
#       Unnamed: 0  Sentence_id  \
# 2215        2215   HONREQ8748
# 2582        2582   GERREQ4428
# 1662        1662  UAEREQ42145
# 3027        3027  GERRES40667
# 4343        4343  UAESSK26982
# ...          ...          ...
# 5399        5399   GERSSK8333
# 1387        1387  HONSSK52070
# 7507        7507   UAESKL6837
# 7242        7242  UAERES26567
# 6437        6437   PHEEXP8387
#
#                                            New_Sentence            Type
# 2215  Schedule flexibility  and resilience, includin...     Requirement
# 2582  Planning out  projects and being involved in p...     Requirement
# 1662  Be an entrepreneurial problem solver who  is p...     Requirement
# 3027  Review & assist with the  Description of Opera...  Responsibility
# 4343  Strong team player  and collaboration with oth...       SoftSkill
# ...                                                 ...             ...
# 5399  Ability to communicate  effectively (oral, wri...       SoftSkill
# 1387  Effective communicator with a wide degree  of ...       SoftSkill
# 7507  Proven ability to lead projects and ensure obj...           Skill
# 7242  Continuously  improve service operational metr...  Responsibility
# 6437  4+ years of strong debugging and operation sup...      Experience
#
# [6400 rows x 4 columns]

# %%
# Data preprocessing - Preprocessing each and every sentence separately

def preprocess(sentence_list):
    row_sentence_list = []

    for i in sentence_list:
        sentence = re.sub(r"\W", " ", str(i)) # keep only words and digits
        sentence = re.sub(r"\d", " ", sentence) # removing the digits
        sentence = re.sub(r"\s+[a-z]\s+" , " " , sentence, flags = re.I) # removing extra spaces
        sentence = re.sub(r"^\s" , " " , sentence) # remove the space at the beginning of the sentence
        sentence = re.sub( r"\s$", " " , sentence) # remove the sapce at the ending of the sentence
        sentence = gensim.utils.simple_preprocess(str(sentence), deacc = True)
        sentence = [word for word in sentence if word not in stop_words]  # for experimenting
        row_sentence_list.append(sentence)

    return  row_sentence_list

# %%
# Data preprocessing  - all rows together to obtain the voacb list

def preprocess_train_data(sentence_list):

        sentence = re.sub(r"\W", " ", str(sentence_list)) # keep only words and digits
        sentence = re.sub(r"\d", " ", sentence) # removing the digits
        sentence = re.sub(r"\s+[a-z]\s+" , " " , sentence, flags = re.I) # removing extra spaces
        sentence = re.sub(r"^\s" , " " , sentence) # remove the space at the beginning of the sentence
        sentence = re.sub( r"\s$", " " , sentence) # remove the sapce at the ending of the sentence
        sentence = gensim.utils.simple_preprocess(str(sentence), deacc = True)
        sentence = [word for word in sentence if word not in stop_words]  # for rexperimenting
        
        return sentence

# %%
# Fetching the list of words present from all the rows given in train data

sentence_list = train["New_Sentence"].tolist()
vocab = preprocess_train_data(sentence_list)

vocab_dict = Counter(vocab) # Fetches the uniques items in the vocab list, and counts its occurences
rare_words = {} # dict to store all the rare words
processed_vocab_dict = {} # processed dict which will not include omitted rare words 

# Find the rare words, i.e. if the occurrence is less than five times
for k,v in vocab_dict.items():
  if v < 5:
    rare_words[k] = v

# Omit all the rare words, whose occrence is less than five times
for k,v in vocab_dict.items():
  if k not in rare_words.keys():
    processed_vocab_dict[k] = v

# %%
# Printing the vocabulary dictionary
print(f"Global Vocabulary : \nCount = {len(vocab_dict)}\n")
print(dict(vocab_dict))
# Out:
# Global Vocabulary :
# Count = 6912
#
# {'schedule': 39, 'flexibility': 12, 'resilience': 4, 'including': 169, 'ability': 505, 'adapt': 15, 'changing': 15, 'uncertain': 2, 'conditions': 5, 'planning': 103, 'projects': 166, 'involved': 11, 'project': 322, 'management': 516, 'decisions': 29, 'entrepreneurial': 4, 'problem': 92, 'solver': 4, 'persuasive': 3, 'tenacious': 2, 'bring': 7, 'cross': 63, 'functional': 135, 'teams': 145, 'together': 5, 'explore': 4, 'new': 124, 'ideas': 15, 'review': 48, 'assist': 31, 'description': 9, 'operation': 11, 'doo': 1, 'test': 131, 'plans': 50, 'user': 42, 'guides': 3, 'strong': 296, 'team': 302, 'player': 13, 'collaboration': 24, 'functions': 46, 'apply': 27, 'defined': 22, 'agile': 69, 'product': 202, 'program': 126, 'practices': 53, 'ensure': 125, 'specific': 30, 'sub': 4, 'component': 17, 'single': 9, 'non': 30, 'complex': 105, 'ensuring': 28, 'delivery': 88, 'time': 62, 'budget': 11, 'scope': 29, 'build': 59, 'advance': 7, 'data': 262, 'analytics': 52, 'technology': 164, 'roadmaps': 3, 'next': 10, 'years': 899, 'alignment': 12, 'strategic': 68, 'business': 517, 'initiatives': 50, 'demonstrate': 24, 'execution': 49, 'long': 16, 'term': 21, 'vision': 12, 'define': 38, 'execute': 25, 'intellectual': 7, 'property': 6, 'strategy': 59, 'primary': 19, 'legal': 12, 'advisor': 4, 'ip': 7, 'matters': 8, 'provide': 109, 'leadership': 
labels = Counter(train["Type"].tolist()) # Fetch all the unique labels

labels
# Out:
# Counter({'Requirement': 1490,
#          'Responsibility': 1682,
#          'SoftSkill': 954,
#          'Experience': 1028,
#          'Skill': 761,
#          'Education': 485})

# %%
# Dividing the training set into subsets based on each unique label

experience_df = train[train['Type'] == "Experience"]
education_df = train[train['Type'] == "Education"]
requirement_df = train[train['Type'] == "Requirement"]
skill_df = train[train['Type'] == "Skill"]
softskill_df = train[train['Type'] == "SoftSkill"]
responsibility_df = train[train['Type'] == "Responsibility"]


responsibility_df
# Out:
#       Unnamed: 0  Sentence_id  \
# 3027        3027  GERRES40667
# 2680        2680  INDRES20388
# 1765        1765  PHERES51459
# 1123        1123  UAERES26624
# 4054        4054  GERRES52232
# ...          ...          ...
# 3280        3280  HONRES29259
# 4831        4831   COGRES1180
# 2106        2106  COGRES36526
# 2679        2679  INDRES39785
# 7242        7242  UAERES26567
#
#                                            New_Sentence            Type
# 3027  Review & assist with the  Description of Opera...  Responsibility
# 2680  Should apply defined Agile Product & Program M...  Responsibility
# 1765  Build and advance data & analytics technology ...  Responsibility
# 1123  Define and  execute our intellectual property ...  Responsibility
# 4054  You will provide leadership in the adoption of...  Responsibility
# ...                                                 ...             ...
# 3280  Apply  engineering knowledge, tools, and princ...  Responsibility
# 4831  As a Senior Full Stack Developer, you will be ...  Responsibility
# 2106  Be  a coach to Security Architects & Security ...  Responsibility
# 2679  You will be involved in every aspect of the th...  Responsibility
# 7242  Continuously  improve service operational metr...  Responsibility
#
# [1682 rows x 4 columns]

# %%
experience_df
# Out:
#       Unnamed: 0  Sentence_id  \
# 2944        2944   UAEEXP9691
# 3181        3181  UAEEXP48504
# 1618        1618  INDEXP31825
# 4794        4794  HONEXP36558
# 3362        3362   GEREXP6238
# ...          ...          ...
# 7887        7887   UAEEXP9727
# 2573        2573  INDEXP10274
# 2768        2768  UAEEXP51060
# 4688        4688   INDEXP2501
# 6437        6437   PHEEXP8387
#
#                                            New_Sentence        Type
# 2944  Five (5)  or more years directly-applicable ex...  Experience
# 3181  Bachelors degree in Engineering, Business  or ...  Experience
# 1618  Minimum of 2 years of experience in the design...  Experience
# 4794    7+ years  of planning/manufacturing experience.  Experience
# 3362                3+  years of scheduling experience.  Experience
# ...                                                 ...         ...
# 7887  Qualification and Skills: Minimum 4 years of e...  Experience
# 2573  2+ years in building  REST/SOAP APIs, MongoDB,...  Experience
# 2768  At least 5 years  of technical leadership expe...  Experience
# 4688  1+ years of experience working with networked ...  Experience
# 6437  4+ years of strong debugging and operation sup...  Experience
#
# [1028 rows x 4 columns]

# %%
# Creating the list of row documents w.r.t to each label

# Create a list of processed row documents
def process_rows(row_words):
  row_document_list = []

  for row in row_words:
    row_document_list.append(removeRareWords(row))

  return row_document_list

# Process the rows of each Type/Class label
# STEPS : 
# 1 - preprocess each row - where, unwanted  character, digits, spaces etc are reomoved. And the
#     function returns the list of splitted words for each row
# 2 - In the second step process, remove the rare words from that list of words for each row

# Experience
exp_sent_list = experience_df["New_Sentence"].tolist()
exp_rows = process_rows(preprocess(exp_sent_list))

# Education
edu_sent_list = education_df["New_Sentence"].tolist()
edu_rows = process_rows(preprocess(edu_sent_list))

# Requirement
req_sent_list = requirement_df["New_Sentence"].tolist()
req_rows = process_rows(preprocess(req_sent_list))

# Skill
skill_sent_list = skill_df["New_Sentence"].tolist()
skill_rows = process_rows(preprocess(skill_sent_list))

# Soft Skill
softskill_sent_list = softskill_df["New_Sentence"].tolist()
softskill_rows = process_rows(preprocess(softskill_sent_list))

# Reponsibility
resp_sent_list = responsibility_df["New_Sentence"].tolist()
resp_rows = process_rows(preprocess(resp_sent_list))

# %%
# Printing the list of processed row documents for each Type, where it displays the row words 
print("List of row documents for Experience Type: ")
print(len(exp_rows))
print(exp_rows)


print("\nList of row documents for Education Type: ")
print(len(edu_rows))
print(edu_rows)

print("\nList of row documents for Skill Type: ")
print(len(skill_rows))
print(skill_rows)

print("\nList of row documents for Requirement Type: ")
print(len(req_rows))
print(req_rows)

print("\nList of row documents for Soft Skill Type: ")
print(len(softskill_rows))
print(softskill_rows)

print("\nList of row documents for Responsibility Type: ")
print(len(resp_rows))
print(resp_rows)
# Out:
# List of row documents for Experience Type:
# 1028
# [Counter({'five': 1, 'years': 1, 'directly': 1, 'applicable': 1, 'experience': 1, 'strategic': 1, 'sourcing': 1, 'procurement': 1, 'supply': 1, 'chain': 1, 'similar': 1, 'function': 1}), Counter({'bachelors': 1, 'degree': 1, 'engineering': 1, 'business': 1, 'relevant': 1, 'discipline': 1, 'plus': 1, 'years': 1, 'related': 1, 'experience': 1}), Counter({'minimum': 1, 'years': 1, 'experience': 1, 'design': 1, 'implementation': 1, 'maintenance': 1, 'honeywell': 1, 'ot': 1, 'enterprise': 1, 'applications': 1, 'connected': 1, 'services': 1}), Counter({'years': 1, 'planning': 1, 'manufacturing': 1, 'experience': 1}), Counter({'years': 1, 'scheduling': 1, 'experience': 1}), Counter({'minimum': 1, 'years': 1, 'experience': 1, 'continuous': 1, 'integration': 1, 'deployment': 1}), Counter({'experience': 2, 'minimum': 1, 'years': 1, 'network': 1, 'security': 1, 'architecture': 1, 'design': 1, 'operations': 1}), Counter({'experience': 1, 'years': 1}), Counter({'years': 1, 'working': 1, 'aerospace': 1, 'industry': 1}), Counter({'years': 1, 'qa': 1, 'lead': 1, 'test': 1, 'manager': 1, 'agile': 1, 'environment': 1}), Counter({'either': 2, 'candidate': 1, 'worked': 1, 'region': 1, 'similar': 1, 'industry': 1, 'house': 1, 'agency': 1, 'capacity': 1}), Counter({'management': 2, 'minimum': 1, 'years': 1, 'experience': 1, 'field': 1, 'project': 1, 'technical': 1}), Counter({'engineering': 2, 'degree': 1, 'years': 1, 'experience': 1, 'strong': 1, 'background': 1, 'software': 1, 'development': 1, 'enterprise': 1, 'product': 1, 'cloud': 1, 'technologies': 1, 'data': 1, 'science': 1, 'advance': 1, 'analytics': 1, 'using': 1, 'ai': 1, 'ml': 1, 'xa': 1}), Counter({'experience': 2, 'years': 1, 'user': 1, 'research': 1, 'strategy': 1, 'enterprise': 1, 'scale': 1, 'domains': 1}), Counter({'minimum': 1, 'years': 1, 'experience': 1, 'process': 1, 'controls': 1, 'industry': 1}), Counter({'years': 1, 'design': 1, 'engineering': 1}), Counter({'years': 1, 'senior': 1, 'level': 1, 'program': 1, 'manager': 1, 'director': 1}), Counter({'years': 1, 'expertise': 1, 'orchestration': 1, 'technologies': 1, 'like': 1, 'kubernetes': 1, 'docker': 1, 'etc': 1}), Counter({'years': 1, 'experience': 1, 'using': 1, 'microsoft': 1, 'office': 1}), Counter({'years': 1, 'experience': 1, 'system': 1, 'engineering': 1}), Counter({'years': 1, 'order': 1, 'management': 1, 'experience': 1}), Counter({'test': 2, 'web': 2, 'services': 2, 'years': 1, 'experience': 1, 'defining': 1, 'strategies': 1, 'scenarios': 1, 'multi': 1, 'facing': 1, 'applications': 1, 'testing': 1, 'especially': 1, 'rest': 1}), Counter({'years': 1, 'experience': 1}), Counter({'years': 1, 'experience': 1, 'embedded': 1, 'data': 1, 'structures': 1}), Counter({'extensive': 1, 'years': 1, 'experience': 1, 'commercial': 1, 'management': 1, 'role': 1, 'including': 1, 'cost': 1}), Counter({'years': 1, 'experience': 1, 'net': 1}), Counter({'years': 1, 'experience': 1, 'supply': 1, 'chain': 1, 'management': 1, 'preferred': 1}), Counter({'years': 1, 'industry': 1, 'experience': 1, 'process': 1, 'simulation': 1, 'platforms': 1, 'like': 1}), Counter({'de': 3, 'vous': 2, 'un': 2, 'ann': 2, 'informatique': 1, 'background': 1, 'technique': 1, 'plus': 1, 'sur': 1, 'windows': 1, 'linux': 1, 'backup': 1, 'cyber': 1, 'en': 1, 'gestion': 1, 'projet': 1, 'dans': 1, 'multi': 1, 'et': 1}), Counter({'must': 1, 'years': 1, 'experience': 1, 'outside': 1, 'sales': 1}), Counter({'years': 1, 'experience': 1, 'devops': 1, 'engineer': 1, 'linux': 1, 'windows': 1, 'environments': 1}), Counter({'qualification': 1, 'design': 1, 'years': 1, 'experience': 1, 'designer': 1, 'digital': 1, 'capacity': 1}), Counter({'years': 1, 'software': 1, 'engineering': 1, 'development': 1, 'experience': 1}), Counter({'least': 1, 'implementation': 1, 'experience': 1}), Counter({'five': 1, 'years': 1, 'experience': 1, 'working': 1, 'engineering': 1, 'manufacturing': 1, 'environment': 1, 'similar': 1, 'position': 1}), Counter({'experience': 1, 'using': 1, 'agile': 1, 'm ...
#
# List of row documents for Education Type:
# 485
# [Counter({'high': 1, 'school': 1, 'diploma': 1, 'equivalent': 1}), Counter({'engineering': 2, 'masters': 1, 'degree': 1, 'electrical': 1, 'physics': 1}), Counter({'tech': 1, 'computer': 1, 'science': 1, 'preferred': 1, 'years': 1, 'professional': 1, 'experience': 1}), Counter({'pursuing': 1, 'bachelors': 1, 'degree': 1, 'field': 1, 'engineering': 1}), Counter({'scrum': 1, 'master': 1, 'certification': 1, 'plus': 1}), Counter({'bachelor': 1, 'science': 1, 'mechanical': 1, 'aerospace': 1, 'engineering': 1}), Counter({'engineering': 2, 'bachelor': 1, 'masters': 1, 'degree': 1, 'mechanical': 1, 'electrical': 1, 'power': 1, 'systems': 1}), Counter({'bachelor': 1, 'science': 1, 'degree': 1, 'engineering': 1, 'prefer
#
# List of row documents for Skill Type:
# 761
# [Counter({'comfortable': 1, 'matrix': 1, 'management': 1, 'environments': 1, 'leading': 1, 'complex': 1, 'projects': 1}), Counter({'sales': 2, 'experience': 1, 'direct': 1, 'channel': 1, 'management': 1, 'handling': 1, 'preferred': 1}), Counter({'knowledgeable': 1, 'data': 1, 'quality': 1, 'metrics': 1, 'monitoring': 1}), Counter({'experience': 1, 'various': 1, 'industrial': 1, 'automation': 1, 'buildings': 1}), Counter({'experience': 1, 'communicating': 1, 'implementing': 1, 'hr': 1, 'programs': 1, 'policies': 1, 'practices': 1, 'processes': 1}), Counter({'understanding': 1, 'export': 1, 'regulations': 1, 'including': 1, 'itar': 1, 'helpful': 1}), Counter({'experience': 2, 'working': 1, 'agile': 1, 'environment': 1, 'desired': 1, 'scrum': 1, 'hands': 1, 'test': 1, 'automation': 1, 'using': 1, 'selenium': 1, 'javascript': 1, 'aws': 1, 'scripting': 1}), Counter({'dummy': 1, 'block': 1, 'text': 1, 'representing': 1, 'nothing': 1}), Counter({'strong': 1, 'computer': 1, 'skills': 1, 'especially': 1, 'microsoft': 1, 'excel': 1, 'word': 1, 'powerpoint': 1, 'respect': 1, 'reports': 1, 'etc': 1}), Counter({'significant': 1, 'experience': 1, 'technical': 1, 'sales': 1, 'account': 1, 'management': 1, 'industry': 1}), Counter({'working': 1, 'experience': 1, 'ms': 1, 'excel': 1, 'limited': 1, 'functions': 1}), Counter({'business': 1, 'fluent': 1, 'written': 1, 'spoken': 1, 'french': 1, 'english': 1}), Counter({'english': 1, 'fluent': 1, 'language': 1}), Counter({'knowledge': 1, 'uat': 1}), Counter({'skills': 2, 'micro': 1, 'focus': 1, 'ibm': 1, 'standard': 1, 'domain': 1}), Counter({'embedded': 2, 'experience': 1, 'programming': 1, 'pi': 1, 'deployment': 1, 'software': 1, 'platforms': 1}), Counter({'expertise': 1, 'cyber': 1, 'security': 1, 'event': 1, 'detection': 1, 'mitigation': 1, 'techniques': 1, 'ot': 1, 'environment': 1}), Counter({'value': 1}), Counter({'sap': 1, 'mrp': 1, 'experience': 1}), Counter({'itil': 1}), Counter({'development': 1, 'experience': 1, 'unit': 1, 'testing': 1, 'frameworks': 1, 'like': 1}), Counter({'high': 1, 'level': 1, 'proficiency': 1, 'microsoft': 1, 'office': 1, 'programs': 1, 'including': 1, 'powerpoint': 1, 'excel': 1}), Counter({'mobile': 1, 'development': 1, 'ios': 1, 'android': 1, 'react': 1, 'native': 1, 'etc': 1}), Counter({'excellent': 1, 'stakeholder': 1, 'management': 1, 'internally': 1, 'externally': 1}), Counter({'understanding': 1, 'experience': 1, 'variety': 1, 'deployment': 1, 'approaches': 1}), Counter({'experience': 2, 'hands': 1, 'large': 1, 'scale': 1, 'deployment': 1, 'genesys': 1, 'framework': 1, 'configuration': 1, 'management': 1, 'routing': 1, 'media': 1, 'components': 1, 'integration': 1, 'cisco': 1}), Counter({'strong': 1, 'understanding': 1, 'electrical': 1, 'components': 1, 'controls': 1, 'stack': 1, 'pressure': 1, 'monitoring': 1}), Counter({'knowledge': 1, 'ci': 1, 'cd': 1, 'integration': 1, 'using': 1, 'jenkins': 1, 'would': 1, 'plus': 1}), Counter({'frameworks': 2, 'proficient': 1, 'agile': 1, 'scrum': 1, 'design': 1, 'thinking': 1, 'ux': 1}), Counter({'global': 1, 'channel': 1, 'demand': 1, 'management': 1}), Counter({'ability': 1, 'effectively': 1, 'identify': 1, 'use': 1, 'offering': 1, 'portfolio': 1, 'performance': 1, 'data': 1, 'make': 1, 'influence': 1, 'business': 1, 'decisions': 1, 'priorities': 1}), Counter({'honeywell': 1, 'product': 1}), Counter({'experience': 1, 'across': 1, 'ict': 1, 'infrastructure': 1, 'networking': 1, 'security': 1, 'software': 1, 'systems': 1, 'applications': 1, 'integration': 1, 'virtualization': 1, 'storage': 1, 'technologies': 1, 'well': 1, 'best': 1, 'practice': 1, 'design': 1, 'implementation': 1}), Counter({'customer': 1, 'marketing': 1, 'functional': 1, 'effectiveness': 1}), Counter({'hands': 1, 'experience': 1, 'html': 1, 'css': 1, 'javascript': 1, 'ui': 1, 'development': 1}), Counter({'strong': 1, 'experience': 1, 'handling': 1, 'xml': 1, 'interfaces': 1}), Counter({'earned': 1, 'value': 1, 'management': 1, 'experience': 1}), Coun ...
#
# List of row documents for Requirement Type:
# 1490
# [Counter({'schedule': 1, 'flexibility': 1, 'including': 1, 'ability': 1, 'adapt': 1, 'changing': 1, 'conditions': 1}), Counter({'planning': 1, 'projects': 1, 'involved': 1, 'project': 1, 'management': 1, 'decisions': 1}), Counter({'problem': 1, 'bring': 1, 'cross': 1, 'functional': 1, 'teams': 1, 'together': 1, 'new': 1, 'ideas': 1}), Counter({'good': 1, 'communication': 1, 'skills': 1, 'written': 1, 'verbal': 1}), Counter({'must': 1, 'havehigh': 1, 'school': 1, 'diploma': 1, 'associates': 1, 'degree': 1, 'computer': 1, 'related': 1, 'discipline': 1}), Counter({'job': 1, 'id': 1, 'req': 1}), Counter({'must': 1, 'know': 1, 'read': 1}), Counter({'able': 1, 'architect': 1, 'design': 1, 'iot': 1, 'based': 1, 'solutions': 1, 'across': 1, 'stack': 1, 'hardware': 1, 'cloud': 1, 'experience': 1, 'preferably': 1}), Counter({'equipment': 2, 'experience': 1, 'design': 1, 'procurement': 1, 'installation': 1, 'mechanical': 1, 'systems': 1, 'also': 1, 'desirable': 1}), Counter({'analysis': 2, 'track': 1, 'record': 1, 'business': 1, 'requirements': 1, 'projects': 1, 'multiple': 1, 'stakeholders': 1, 'high': 1, 'organizational': 1, 'process': 1, 'complexity': 1}), Counter({'teams': 2, 'ability': 1, 'work': 1, 'effectively': 1, 'collaborate': 1, 'achieve': 1, 'goals': 1}), Counter({'experience': 1, 'knowledge': 1, 'physics': 1}), Counter({'understanding': 1, 'security': 1, 'concepts': 1, 'must': 1}), Counter({'effective': 1, 'clear': 1, 'communication': 1, 'skills': 1, 'good': 1, 'ability': 1, 'work': 1, 'others': 1}), Counter({'ability': 1, 'run': 1, 'vertical': 1}), Counter({'six': 1, 'sigma': 1, 'lean': 1, 'expert': 1, 'preferred': 1, 'hos': 1, 'experience': 1, 'plus': 1}), Counter({'prior': 1, 'experience': 1, 'planning': 1, 'scheduling': 1, 'tracking': 1, 'status': 1, 'reporting': 1}), Counter({'ability': 1, 'deliver': 1, 'complex': 1, 'situations': 1, 'problems': 1, 'without': 1, 'guidance': 1, 'supervision': 1}), Counter({'must': 1, 'innovative': 1, 'thinker': 1, 'quick': 1, 'solutions': 1, 'generate': 1, 'ideas': 1}), Counter({'demonstrated': 1, 'ability': 1, 'without': 1, 'authority': 1, 'innovative': 1, 'ideas': 1, 'approaches': 1}), Counter({'direct': 1, 'personnel': 1, 'work': 1, 'supervision': 1, 'abilities': 1}), Counter({'java': 2, 'candidate': 1, 'work': 1, 'project': 1, 'requests': 1, 'possess': 1, 'strong': 1, 'working': 1, 'experience': 1, 'core': 1, 'html': 1}), Counter({'strong': 1, 'business': 1, 'acumen': 1, 'experience': 1, 'working': 1, 'across': 1, 'different': 1, 'departments': 1, 'organization': 1}), Counter({'outstanding': 1, 'relationship': 1, 'influencing': 1, 'others': 1, 'levels': 1, 'organization': 1}), Counter({'knowledge': 1, 'automation': 1, 'tools': 1, 'like': 1, 'would': 1, 'helpful': 1}), Counter({'retail': 2, 'systems': 2, 'broad': 1, 'knowledge': 1, 'capabilities': 1, 'across': 1, 'multiple': 1, 'platforms': 1, 'including': 1, 'core': 1, 'sap': 1, 'crm': 1}), Counter({'work': 1, 'experience': 1, 'required': 1, 'yrs': 1}), Counter({'key': 1, 'program': 1, 'leaders': 1, 'domain': 1, 'engines': 1, 'power': 1, 'systems': 1}), Counter({'excellent': 1, 'communication': 1, 'presentation': 1, 'skills': 1, 'oral': 1, 'written': 1}), Counter({'practical': 1, 'experience': 1, 'tactical': 1, 'avionics': 1, 'systems': 1, 'related': 1, 'test': 1, 'equipment': 1}), Counter({'ability': 1, 'establish': 1, 'maintain': 1, 'influential': 1, 'relationships': 1, 'levels': 1, 'business': 1}), Counter({'skill': 1, 'track': 1, 'key': 1, 'performance': 1, 'metrics': 1, 'improvements': 1, 'engineering': 1, 'design': 1, 'quality': 1, 'deliver': 1, 'ability': 1, 'improve': 1, 'processes': 1}), Counter({'electrical': 2, 'basic': 1, 'knowledge': 1, 'diagrams': 1}), Counter({'vulnerability': 1}), Counter({'able': 1, 'work': 1, 'multiple': 1, 'teams': 1}), Counter({'experience': 1, 'space': 1, 'optical': 1, 'communication': 1, 'system': 1, 'design': 1}), Counter({'may': 2, 'must': 1, 'bachelors': 1, 'masters': 1, 'degree': 1, 'accredi ...
#
# List of row documents for Soft Skill Type:
# 954
# [Counter({'strong': 1, 'team': 1, 'player': 1, 'collaboration': 1, 'functions': 1}), Counter({'strong': 1, 'collaboration': 1, 'technical': 1, 'communication': 1, 'skills': 1, 'written': 1, 'verbal': 1}), Counter({'flexible': 1, 'approach': 1, 'work': 1, 'attitude': 1}), Counter({'knowledge': 1, 'french': 1, 'language': 1, 'least': 1, 'level': 1}), Counter({'demonstrate': 1, 'ability': 1, 'understand': 1, 'customer': 1, 'requirements': 1, 'priorities': 1, 'make': 1, 'right': 1, 'business': 1, 'decisions': 1}), Counter({'learn': 1, 'adapt': 1}), Counter({'experience': 1, 'presenting': 1, 'level': 1, 'executives': 1, 'senior': 1, 'business': 1, 'technology': 1, 'leaders': 1, 'must': 1, 'influential': 1}), Counter({'ability': 1, 'develop': 1, 'high': 1, 'performing': 1, 'teams': 1}), Counter({'ability': 1, 'prioritize': 1, 'problem': 1, 'solve': 1}), Counter({'challenging': 1, 'multi': 1, 'leadership': 1, 'role': 1, 'requires': 1, 'individual': 1, 'across': 1, 'several': 1, 'concurrent': 1, 'task': 1, 'assignments': 1}), Counter({'ability': 1, 'influence': 1, 'cross': 1, 'functional': 1, 'teams': 1, 'deliver': 1, 'optimal': 1, 'outcomes': 1}), Counter({'flexible': 1, 'mindset': 1, 'diverse': 1, 'culture': 1, 'environment': 1}), Counter({'ideal': 1, 'candidate': 1}), Counter({'excellent': 1, 'team': 1, 'interaction': 1, 'communication': 1, 'skills': 1}), Counter({'experience': 1, 'customer': 1, 'facing': 1, 'role': 1, 'escalation': 1, 'management': 1, 'status': 1, 'reporting': 1}), Counter({'attention': 1, 'detail': 1, 'adherence': 1, 'standards': 1}), Counter({'excellent': 1, 'analytical': 1, 'problem': 1, 'solving': 1, 'skills': 1}), Counter({'ability': 1, 'define': 1, 'investigate': 1, 'solve': 1, 'technical': 1, 'problems': 1}), Counter({'good': 1, 'communication': 1, 'negotiation': 1, 'skills': 1, 'xa': 1}), Counter({'problem': 1, 'solving': 1, 'root': 1, 'cause': 1, 'analysis': 1}), Counter({'strong': 1, 'communicator': 1, 'high': 1, 'level': 1, 'interpersonal': 1, 'skills': 1, 'dynamic': 1, 'approach': 1, 'others': 1}), Counter({'job': 1, 'description': 1}), Counter({'key': 1, 'essential': 1, 'skills': 1}), Counter({'capacitxe': 1, 'xe': 1, 'au': 1}), Counter({'also': 1, 'able': 1, 'apply': 1, 'organizational': 1, 'critical': 1, 'thinking': 1, 'oral': 1, 'written': 1, 'communication': 1, 'skills': 1}), Counter({'demonstrated': 1, 'facilitation': 1, 'skills': 1}), Counter({'excellent': 1, 'english': 1, 'written': 1, 'verbal': 1}), Counter({'account': 1, 'analysis': 1, 'planning': 1}), Counter({'critical': 1, 'thinking': 1, 'strong': 1, 'problem': 1, 'solving': 1, 'skills': 1, 'able': 1, 'investigate': 1, 'follow': 1, 'appropriately': 1, 'make': 1, 'necessary': 1}), Counter({'self': 1, 'starter': 1, 'ability': 1, 'work': 1}), Counter({'strong': 1, 'interpersonal': 1, 'skills': 1, 'ability': 1, 'form': 1, 'professional': 1, 'relationships': 1}), Counter({'dummy': 1, 'block': 1, 'text': 1, 'representing': 1, 'nothing': 1}), Counter({'self': 1, 'motivated': 1, 'individual': 1, 'good': 1, 'communication': 1, 'interpersonal': 1, 'skills': 1, 'ability': 1, 'sell': 1, 'system': 1, 'enhancements': 1}), Counter({'experience': 1, 'working': 1, 'client': 1, 'facing': 1, 'roles': 1}), Counter({'ability': 1, 'work': 1, 'collaboratively': 1, 'virtual': 1, 'highly': 1, 'matrixed': 1, 'environment': 1}), Counter({'flexible': 1, 'willing': 1, 'travel': 1}), Counter({'problem': 1, 'solving': 1, 'skills': 1}), Counter({'strong': 1, 'leadership': 1, 'skills': 1, 'cross': 1, 'cultural': 1, 'environment': 1}), Counter({'proven': 1, 'experience': 1, 'self': 1, 'starter': 1, 'enterprise': 1, 'environment': 1}), Counter({'teams': 2, 'ability': 1, 'drive': 1, 'change': 1, 'within': 1, 'peer': 1, 'group': 1, 'customer': 1, 'business': 1, 'higher': 1, 'level': 1, 'across': 1, 'non': 1, 'value': 1, 'added': 1, 'activities': 1}), Counter({'key': 1}), Counter({'capacitxe': 1, 'xe': 1, 'les': 1}), Counter({'effective': 1, 'customer': 1, 'facing': 1, 'commun ...
#
# List of row documents for Responsibility Type:
# 1682
# [Counter({'review': 1, 'assist': 1, 'description': 1, 'operation': 1, 'test': 1, 'plans': 1, 'user': 1}), Counter({'project': 2, 'apply': 1, 'defined': 1, 'agile': 1, 'product': 1, 'program': 1, 'management': 1, 'practices': 1, 'ensure': 1, 'specific': 1, 'component': 1, 'single': 1, 'non': 1, 'complex': 1, 'ensuring': 1, 'delivery': 1, 'time': 1, 'budget': 1, 'scope': 1}), Counter({'build': 1, 'advance': 1, 'data': 1, 'analytics': 1, 'technology': 1, 'next': 1, 'years': 1, 'alignment': 1, 'strategic': 1, 'business': 1, 'initiatives': 1, 'demonstrate': 1, 'execution': 1, 'long': 1, 'term': 1, 'vision': 1}), Counter({'define': 1, 'execute': 1, 'intellectual': 1, 'property': 1, 'strategy': 1, 'primary': 1, 'legal': 1, 'ip': 1, 'matters': 1}), Counter({'provide': 1, 'leadership': 1, 'adoption': 1, 'smart': 1, 'factory': 1, 'standards': 1, 'ability': 1, 'scale': 1, 'across': 1, 'honeywell': 1}), Counter({'customer': 2, 'monitor': 1, 'operations': 1, 'field': 1, 'data': 1, 'assess': 1, 'product': 1, 'health': 1, 'proactively': 1, 'address': 1, 'technical': 1, 'issues': 1, 'relations': 1}), Counter({'also': 1, 'collaborate': 1, 'senior': 1, 'engineers': 1, 'help': 1, 'develop': 1, 'testing': 1, 'cloud': 1, 'technologies': 1}), Counter({'sales': 2, 'drives': 1, 'growth': 1, 'defined': 1, 'area': 1, 'delivers': 1, 'individual': 1, 'targets': 1}), Counter({'coe': 2, 'identify': 1, 'establish': 1, 'manage': 1, 'partnerships': 1, 'lines': 1, 'services': 1, 'work': 1, 'teams': 1, 'develop': 1, 'new': 1, 'service': 1, 'offerings': 1}), Counter({'dummy': 1, 'block': 1, 'text': 1, 'representing': 1, 'nothing': 1}), Counter({'know': 1, 'products': 1, 'processes': 1, 'detail': 1, 'control': 1, 'plans': 1}), Counter({'learn': 1, 'understand': 1, 'products': 1, 'technology': 1, 'sell': 1, 'building': 1, 'customers': 1}), Counter({'track': 1, 'orders': 1}), Counter({'application': 1, 'security': 1, 'practices': 1, 'ci': 1, 'cd': 1, 'pipelines': 1, 'devops': 1, 'environments': 1}), Counter({'plan': 2, 'de': 1}), Counter({'design': 2, 'fabrication': 1, 'delivery': 1, 'new': 1, 'existing': 1, 'products': 1, 'systems': 1, 'meet': 1, 'aop': 1, 'business': 1, 'lead': 1, 'maintenance': 1, 'activities': 1, 'site': 1, 'training': 1, 'equipment': 1, 'extensive': 1, 'knowledge': 1, 'virtualization': 1, 'leading': 1, 'coordination': 1, 'virtual': 1, 'system': 1, 'globally': 1}), Counter({'engineering': 2, 'mathematical': 1, 'physical': 1, 'science': 1, 'advanced': 1, 'mechanical': 1, 'technologies': 1, 'objectives': 1}), Counter({'project': 1, 'issues': 1, 'deploy': 1, 'meet': 1, 'productivity': 1, 'quality': 1, 'customers': 1, 'satisfaction': 1, 'goals': 1, 'objectives': 1}), Counter({'manage': 1, 'existing': 1, 'partners': 1, 'building': 1, 'relationships': 1, 'work': 1, 'partnership': 1, 'deliver': 1, 'outstanding': 1, 'business': 1, 'results': 1}), Counter({'provide': 1, 'project': 1, 'leadership': 1, 'direction': 1, 'one': 1, 'projects': 1, 'maintaining': 1, 'high': 1, 'quality': 1, 'level': 1, 'service': 1}), Counter({'ensure': 1, 'project': 1, 'schedules': 1, 'contract': 1, 'requirements': 1, 'meet': 1, 'industry': 1, 'quality': 1, 'standards': 1}), Counter({'good': 1, 'decision': 1, 'making': 1, 'form': 1, 'best': 1, 'overall': 1, 'solution': 1, 'company': 1}), Counter({'service': 2, 'develop': 1, 'self': 1, 'models': 1, 'data': 1, 'analytics': 1, 'using': 1, 'power': 1, 'bi': 1}), Counter({'vous': 1, 'la': 1, 'dans': 1, 'le': 1, 'de': 1, 'solutions': 1}), Counter({'achieving': 1, 'individual': 1, 'sales': 1, 'targets': 1, 'assigned': 1, 'region': 1}), Counter({'sales': 1, 'marketing': 1, 'fully': 1, 'understand': 1, 'product': 1, 'communication': 1, 'needs': 1}), Counter({'evaluate': 1, 'material': 1, 'flow': 1}), Counter({'identify': 1, 'areas': 1, 'process': 1, 'improvements': 1}), Counter({'program': 2, 'define': 1, 'structure': 1, 'aligned': 1}), Counter({'recommend': 1, 'improvements': 1, 'production': 1, 'methods': 1, 'equipment': 1, 'performa ...

# %%
# Calculate the probability of occurence for each word present in processed vocab list
# input - processed_vocab_dict, row_document_list

total_rows = list_of_all_row_docs = exp_rows + edu_rows + skill_rows + req_rows + softskill_rows + resp_rows

def calcualteProbabilityOfOccurence(processed_vocab_dict, row_document_list):

  prob_occurence_doc = {}

  total_doc_count = len(row_document_list)

  for word in processed_vocab_dict:

    occurence  = 0

    for row_words in row_document_list:

      if word in row_words.keys():
        occurence += 1
      
    prob_occurence = occurence/total_doc_count

    prob_occurence_doc[word] = prob_occurence

  return prob_occurence_doc

# %%
print("Probabily of the occrence of each word in the processed vocabulary: \n")
prob_occurence = calcualteProbabilityOfOccurence(processed_vocab_dict, total_rows)


prob_occurence_df = pd.DataFrame.from_dict(prob_occurence, orient ='index') 
prob_occurence_df.columns = ["Probability Occurence"]
prob_occurence_df
# Out:
# Probabily of the occrence of each word in the processed vocabulary:
#              Probability Occurence
# schedule                  0.005938
# flexibility               0.001875
# including                 0.026094
# ability                   0.077500
# adapt                     0.002344
# ...                            ...
# vault                     0.000469
# legacy                    0.000781
# desk                      0.000781
# secret                    0.000625
# alfresco                  0.000156
#
# [1694 rows x 1 columns]

# %%
# Calculate conditional probabilties for each each word in the vocabulary w.r.t each Class label

experience_cond_prob = calcualteProbabilityOfOccurence(processed_vocab_dict, exp_rows)

education_cond_prob = calcualteProbabilityOfOccurence(processed_vocab_dict, edu_rows)

requirement_cond_prob = calcualteProbabilityOfOccurence(processed_vocab_dict, req_rows)

skill_cond_prob = calcualteProbabilityOfOccurence(processed_vocab_dict, skill_rows)

softskill_cond_prob = calcualteProbabilityOfOccurence(processed_vocab_dict, softskill_rows)

responsibility_cond_prob = calcualteProbabilityOfOccurence(processed_vocab_dict, resp_rows)

# %%
# Conditional Probabilties w.r.t class type - Experience

display_df = pd.DataFrame.from_dict(experience_cond_prob, orient ='index') 
display_df.columns = ["P({word}|Experience)"]
display_df
# Out:
#              P({word}|Experience)
# schedule                 0.000973
# flexibility              0.000000
# including                0.025292
# ability                  0.007782
# adapt                    0.000000
# ...                           ...
# vault                    0.000973
# legacy                   0.000973
# desk                     0.002918
# secret                   0.000000
# alfresco                 0.000973
#
# [1694 rows x 1 columns]

# %%
# Conditional Probabilties w.r.t class type - Education

display_df = pd.DataFrame.from_dict(education_cond_prob, orient ='index') 
display_df.columns = ["P({word}|Education)"]
display_df
# Out:
#              P({word}|Education)
# schedule                0.000000
# flexibility             0.000000
# including               0.004124
# ability                 0.004124
# adapt                   0.000000
# ...                          ...
# vault                   0.000000
# legacy                  0.000000
# desk                    0.000000
# secret                  0.000000
# alfresco                0.000000
#
# [1694 rows x 1 columns]

# %%
# Conditional Probabilties w.r.t class type - Requirement

display_df = pd.DataFrame.from_dict(requirement_cond_prob, orient ='index') 
display_df.columns = ["P({word}|Requirement)"]
display_df
# Out:
#              P({word}|Requirement)
# schedule                  0.009396
# flexibility               0.002685
# including                 0.022819
# ability                   0.163758
# adapt                     0.004027
# ...                            ...
# vault                     0.000671
# legacy                    0.001342
# desk                      0.000671
# secret                    0.002685
# alfresco                  0.000000
#
# [1694 rows x 1 columns]

# %%
# Conditional Probabilties w.r.t class type - Skill

display_df = pd.DataFrame.from_dict(skill_cond_prob, orient ='index') 
display_df.columns = ["P({word}|Skill)"]
display_df
# Out:
#              P({word}|Skill)
# schedule            0.002628
# flexibility         0.000000
# including           0.028909
# ability             0.034166
# adapt               0.001314
# ...                      ...
# vault               0.001314
# legacy              0.000000
# desk                0.001314
# secret              0.000000
# alfresco            0.000000
#
# [1694 rows x 1 columns]

# %%
# Conditional Probabilties w.r.t class type - Soft Skills

display_df = pd.DataFrame.from_dict(softskill_cond_prob, orient ='index') 
display_df.columns = ["P({word}|Soft Skill)"]
display_df
# Out:
#              P({word}|Soft Skill)
# schedule                 0.005241
# flexibility              0.007338
# including                0.010482
# ability                  0.208595
# adapt                    0.006289
# ...                           ...
# vault                    0.000000
# legacy                   0.000000
# desk                     0.000000
# secret                   0.000000
# alfresco                 0.000000
#
# [1694 rows x 1 columns]

# %%
# Conditional Probabilties w.r.t class type - Responsibility

display_df = pd.DataFrame.from_dict(responsibility_cond_prob, orient ='index') 
display_df.columns = ["P({word}|Responsibility)"]
display_df
# Out:
#              P({word}|Responsibility)
# schedule                     0.009512
# flexibility                  0.000595
# including                    0.043401
# ability                      0.010107
# adapt                        0.001189
# ...                               ...
# vault                        0.000000
# legacy                       0.001189
# desk                         0.000000
# secret                       0.000000
# alfresco                     0.000000
#
# [1694 rows x 1 columns]

# %%
# Defining the Naive Bayes function - which computes the probability of each class using Naive Bayes theorem
# And, the class with the highest probability becomes the predicted label for the given test sentence

# calculate the probability of the classes

total_rows = list_of_all_row_docs = exp_rows + edu_rows + skill_rows + req_rows + softskill_rows + resp_rows

prob_experience_class = len(experience_df)/len(total_rows)

prob_education_class = len(education_df)/len(total_rows)

prob_requirement_class = len(requirement_df)/len(total_rows)

prob_skill_class = len(skill_df)/len(total_rows)

prob_softskill_class = len(softskill_df)/len(total_rows)

prob_resposibility_class = len(responsibility_df)/len(total_rows)


def naiveBayes(exp_values, edu_values, req_values, skill_values, softskill_values, resp_values):

  prob_dict = {}

  # compute the probability of the sentence w.r.t to Experience class
  prob_exp = reduce(lambda a, b: a * b, exp_values) * prob_experience_class
  prob_dict["Experience"] = prob_exp


  # compute the probability of the sentence w.r.t to Education class
  prob_edu = reduce(lambda a, b: a * b, edu_values) * prob_education_class
  prob_dict["Education"] = prob_edu


  # compute the probability of the sentence w.r.t to Requirement class
  prob_req = reduce(lambda a, b: a * b, req_values) * prob_requirement_class
  prob_dict["Requirement"] = prob_req


  # compute the probability of the sentence w.r.t to Skill class
  prob_skill = reduce(lambda a, b: a * b, skill_values) * prob_skill_class
  prob_dict["Skill"] = prob_skill


  # compute the probability of the sentence w.r.t to Soft Skill class
  prob_softskill = reduce(lambda a, b: a * b, softskill_values) * prob_softskill_class
  prob_dict["SoftSkill"] = prob_softskill


  # compute the probability of the sentence w.r.t to Responsibility class
  prob_resp = reduce(lambda a, b: a * b, resp_values) * prob_resposibility_class
  prob_dict["Responsibility"] = prob_resp

  # Fetch the class with the max probability
  predicted_class = max(prob_dict, key=prob_dict.get)

  # Return the predicted class
  return predicted_class

# %%
# In this step, considering the dev data to predict the class type for each given sentence in dev data set
# displaying dev data

dev
# Out:
#       Unnamed: 0  Sentence_id  \
# 6890        6890  UAESSK18283
# 7711        7711  PHEEDU46062
# 5000        5000  PHEEXP49816
# 5853        5853  INDREQ20702
# 1279        1279  PHERES28909
# ...          ...          ...
# 3236        3236  PHEEDU34168
# 6172        6172   UAEEDU9612
# 1540        1540   PHERES1560
# 1217        1217   INDRES2060
# 2681        2681  HONREQ45945
#
#                                            New_Sentence            Type
# 6890  Manage multiple priorities and work independen...       SoftSkill
# 7711     Bachelors Degree  in Engineering or Chemistry.       Education
# 5000                            Experience:  6-8 Years.      Experience
# 5853                   Travel Requirements:  No Travel.     Requirement
# 1279  Debug  and maintain test application and sourc...  Responsibility
# ...                                                 ...             ...
# 3236  Critical SkillsProvides a critical role in ini...       Education
# 6172    Candidates with  masters degree are preferable.       Education
# 1540  Coordinate user experience and design activiti...  Responsibility
# 1217  Collaborate  with Sales, Marketing, Technology...  Responsibility
# 2681  Candidate will be  responsible for Leading Aer...     Requirement
#
# [800 rows x 4 columns]

# %%
# Preprocess dev data
# Splitting each document's sentence into lits of words
print(f"No. of dev data documnets: {len(dev)}\n")
processed_dev_data = preprocess(dev["New_Sentence"].tolist())
# Out:
# No. of dev data documnets: 800

# %%
def predictClassType(data, experience_cond_prob, education_cond_prob, requirement_cond_prob, skill_cond_prob, softskill_cond_prob, responsibility_cond_prob):

  # Predict the class type for each sentence given in each row of the dev data
  predicted_label_list = [] # place holder list to store all the predicted values

  for row in data:

    #Creating the place holder lists for each class that will store the conditional prob of each word in the given sentence
    exp_list = []
    edu_list = []
    req_list = []
    skill_list = []
    softskill_list = []
    resp_list = []

    # For each word in the sentence - fetch it's conditional probability w.r.t each class from the previously calculated dict
    # And, append those values to their respective lists
    # If the word is not present in the train data, then ignore that value by just taking 1 as it default conditional prob value

    for word in row:
      exp_list.append(experience_cond_prob.get(word, 1))

      edu_list.append(education_cond_prob.get(word, 1))

      req_list.append(requirement_cond_prob.get(word, 1))

      skill_list.append(skill_cond_prob.get(word, 1))

      softskill_list.append(softskill_cond_prob.get(word, 1))

      resp_list.append(responsibility_cond_prob.get(word, 1))

    # Apply naive bayes formula to compute the class type of each sentence
    predicted_label = naiveBayes(exp_list, edu_list, req_list, skill_list, softskill_list, resp_list)

    predicted_label_list.append(predicted_label)
  
  return predicted_label_list

# %%
# Function call to predict the class type of each document in the dev data
predicted_label_list = predictClassType(processed_dev_data, experience_cond_prob, education_cond_prob, requirement_cond_prob, skill_cond_prob, softskill_cond_prob, responsibility_cond_prob)

# %%
# Display the predicted labels for each sentence in dev data
print("Predicted Class Type for each document in dev data: \n")
display_df = pd.DataFrame(list(zip(dev["New_Sentence"].tolist(), predicted_label_list)), columns = ["Sentence", "Predicted Class Type"])
display_df
# Out:
# Predicted Class Type for each document in dev data:
#                                               Sentence Predicted Class Type
# 0    Manage multiple priorities and work independen...            SoftSkill
# 1       Bachelors Degree  in Engineering or Chemistry.            Education
# 2                              Experience:  6-8 Years.           Experience
# 3                     Travel Requirements:  No Travel.          Requirement
# 4    Debug  and maintain test application and sourc...       Responsibility
# ..                                                 ...                  ...
# 795  Critical SkillsProvides a critical role in ini...       Responsibility
# 796    Candidates with  masters degree are preferable.          Requirement
# 797  Coordinate user experience and design activiti...       Responsibility
# 798  Collaborate  with Sales, Marketing, Technology...       Responsibility
# 799  Candidate will be  responsible for Leading Aer...       Responsibility
#
# [800 rows x 2 columns]

# %%
# Defining the function to calculate the accuracy 
# actual_label_list = dev["Type"].tolist()

def calculateAccuracy(predicted_label_list, actual_label_list, total_count):

  correct_predicted_count = 0
  index = 0

  for i in range(total_count):
    if predicted_label_list[i] == actual_label_list[i]:
      correct_predicted_count += 1

  accuracy = (correct_predicted_count/total_count) * 100

  print(f"Acccuracy : {accuracy: .2f} %")

calculateAccuracy(predicted_label_list, dev["Type"].tolist(), len(dev))
# Out:
# Acccuracy :  59.62 %

# %%
# Implement Laplace smooting

def laplaceSmoothing(processed_vocab_dict, row_document_list, smoothing_param):

  prob_occurence_doc = {}

  total_doc_count = len(row_document_list)

  # Smoothing parameter to perform Laplace smoothing - smoothing_param

  # where k is the no. of feature in data, i.e total no. of words in processed voab dict
  k_value = len(processed_vocab_dict) 

  for word in processed_vocab_dict:

    occurence  = 0

    for row_words in row_document_list:

      if word in row_words.keys():
        occurence += 1

    # Calculate the condiional probability by applying laplace smoothing technique
    prob_occurence = (occurence + smoothing_param)/(total_doc_count + (k_value * smoothing_param))

    prob_occurence_doc[word] = prob_occurence

  return prob_occurence_doc


def laplaceSmoothingForMissingWord(word, k_value, n_value, smoothing_param):

  # Smoothing parameter to perform Laplace smoothing - smoothing_param

  prob_occurence = smoothing_param/(n_value + (k_value * smoothing_param))

  return prob_occurence

# %%
# Calculate conditional probabilties for each each word in the vocabulary w.r.t each Class label

def calculateConditionalProbabilitiy(smoothing_param):


  exp_cond_prob_laplace = laplaceSmoothing(processed_vocab_dict, exp_rows, smoothing_param)

  edu_cond_prob_laplace = laplaceSmoothing(processed_vocab_dict, edu_rows, smoothing_param)

  req_cond_prob_laplace = laplaceSmoothing(processed_vocab_dict, req_rows, smoothing_param)

  skill_cond_prob_laplace = laplaceSmoothing(processed_vocab_dict, skill_rows, smoothing_param)

  softskill_cond_prob_laplace = laplaceSmoothing(processed_vocab_dict, softskill_rows, smoothing_param)

  responsibility_cond_prob_laplace = laplaceSmoothing(processed_vocab_dict, resp_rows, smoothing_param)

  return exp_cond_prob_laplace, edu_cond_prob_laplace, req_cond_prob_laplace, skill_cond_prob_laplace, softskill_cond_prob_laplace, responsibility_cond_prob_laplace


exp_cond_prob_laplace, edu_cond_prob_laplace, req_cond_prob_laplace, skill_cond_prob_laplace, softskill_cond_prob_laplace, responsibility_cond_prob_laplace = calculateConditionalProbabilitiy(1)

# %%
# Conditional Probabilties w.r.t class type - Experience
# If we observe the conditional probabilites of each word w.r.t to Experience class type - 
# none of the values are 0 - after performing laplace smoothing

print("Coniditonal probabilities w.r.t Experience class type - after performing Laplace Smoothing: \n")
display_df = pd.DataFrame.from_dict(exp_cond_prob_laplace, orient ='index') 
display_df.columns = ["P({word}|Experience)"]
display_df
# Out:
# Coniditonal probabilities w.r.t Experience class type - after performing Laplace Smoothing:
#              P({word}|Experience)
# schedule                 0.000735
# flexibility              0.000367
# including                0.009919
# ability                  0.003306
# adapt                    0.000367
# ...                           ...
# vault                    0.000735
# legacy                   0.000735
# desk                     0.001470
# secret                   0.000367
# alfresco                 0.000735
#
# [1694 rows x 1 columns]

# %%
def predictClassTypeUsingSmoothing(data, experience_cond_prob, education_cond_prob, requirement_cond_prob, skill_cond_prob, softskill_cond_prob, responsibility_cond_prob, smoothing_param):

  # Predict the class type for each sentence given in each row of the dev data
  predicted_label_list = [] # place holder list to store all the predicted values

  k_value = len(processed_vocab_dict)

  for row in data:

    #Creating the place holder lists for each class that will store the conditional prob of each word in the given sentence
    exp_list = []
    edu_list = []
    req_list = []
    skill_list = []
    softskill_list = []
    resp_list = []

    # For each word in the sentence - fetch it's conditional probability w.r.t each class from the previously calculated dict
    # And, append those values to their respective lists
    # If the word is not present in the train data, calculate the prob by using Laplace smoothing technique

    for word in row:
      exp_list.append(experience_cond_prob.get(word, laplaceSmoothingForMissingWord(word, k_value, len(experience_df), smoothing_param)))

      edu_list.append(education_cond_prob.get(word, laplaceSmoothingForMissingWord(word, k_value, len(education_df), smoothing_param)))

      req_list.append(requirement_cond_prob.get(word, laplaceSmoothingForMissingWord(word, k_value, len(requirement_df), smoothing_param)))

      skill_list.append(skill_cond_prob.get(word, laplaceSmoothingForMissingWord(word, k_value, len(skill_df), smoothing_param)))

      softskill_list.append(softskill_cond_prob.get(word, laplaceSmoothingForMissingWord(word, k_value, len(softskill_df), smoothing_param)))

      resp_list.append(responsibility_cond_prob.get(word, laplaceSmoothingForMissingWord(word, k_value, len(responsibility_df), smoothing_param)))

    # Apply naive bayes formula to compute the class type of each sentence
    predicted_label = naiveBayes(exp_list, edu_list, req_list, skill_list, softskill_list, resp_list)

    predicted_label_list.append(predicted_label)
  

  return predicted_label_list

# %%
# Function call to predict the class type of each document in the dev data

predicted_label_list = predictClassTypeUsingSmoothing(processed_dev_data, exp_cond_prob_laplace, edu_cond_prob_laplace, req_cond_prob_laplace, skill_cond_prob_laplace, softskill_cond_prob_laplace, responsibility_cond_prob_laplace, 1)

# %%
# Display the predicted labels for each sentence in dev data
print("Predicted Class Type for each document in dev data, after Laplace Smoothing: \n")
display_df = pd.DataFrame(list(zip(dev["New_Sentence"].tolist(), predicted_label_list)), columns = ["Sentence", "Predicted Class Type"])
display_df
# Out:
# Predicted Class Type for each document in dev data, after Laplace Smoothing:
#                                               Sentence Predicted Class Type
# 0    Manage multiple priorities and work independen...            SoftSkill
# 1       Bachelors Degree  in Engineering or Chemistry.            Education
# 2                              Experience:  6-8 Years.           Experience
# 3                     Travel Requirements:  No Travel.          Requirement
# 4    Debug  and maintain test application and sourc...       Responsibility
# ..                                                 ...                  ...
# 795  Critical SkillsProvides a critical role in ini...       Responsibility
# 796    Candidates with  masters degree are preferable.          Requirement
# 797  Coordinate user experience and design activiti...       Responsibility
# 798  Collaborate  with Sales, Marketing, Technology...       Responsibility
# 799  Candidate will be  responsible for Leading Aer...       Responsibility
#
# [800 rows x 2 columns]

# %%
# Calculate the accuracy after performing Laplace Smoothing - smoothing parameter = 1

print("After performing Laplace Smoothing: \n\nSmoothing parameter (alpha) = 1\n")
calculateAccuracy(predicted_label_list, dev["Type"].tolist(), len(dev))
# Out:
# After performing Laplace Smoothing:
#
# Smoothing parameter (alpha) = 1
#
# Acccuracy :  64.62 %

# %%
def experimentSmoothing(smoothing_param):
 

  # Calculate Condtional Probabilities
  exp_cond_prob_laplace, edu_cond_prob_laplace, req_cond_prob_laplace, skill_cond_prob_laplace, softskill_cond_prob_laplace, responsibility_cond_prob_laplace = calculateConditionalProbabilitiy(smoothing_param)

  # Function call to predict the class type of each document in the dev data
  predicted_label_list = predictClassTypeUsingSmoothing(processed_dev_data, exp_cond_prob_laplace, edu_cond_prob_laplace, req_cond_prob_laplace, skill_cond_prob_laplace, softskill_cond_prob_laplace, responsibility_cond_prob_laplace, smoothing_param)

  # Calculate the accuracy after performing Laplace Smoothing
  print(f"After performing Laplace Smoothing: \n\nSmoothing parameter (alpha) = {smoothing_param}\n")
  calculateAccuracy(predicted_label_list, dev["Type"].tolist(), len(dev))

# %%
# Experimenting with smoothing_param = 1

experimentSmoothing(1)
# Out:
# After performing Laplace Smoothing:
#
# Smoothing parameter (alpha) = 1
#
# Acccuracy :  64.62 %

# %%
# Experimenting with smoothing_param = 100 

experimentSmoothing(100)
# Out:
# After performing Laplace Smoothing:
#
# Smoothing parameter (alpha) = 100
#
# Acccuracy :  57.25 %

# %%
# Experimenting with smoothing_param = 200

experimentSmoothing(200)
# Out:
# After performing Laplace Smoothing:
#
# Smoothing parameter (alpha) = 200
#
# Acccuracy :  55.12 %

# %%
# Use the test dataset - by the experiments performed above - choose the best smoothing param value

# %%
# Displaying the test data

test
# Out:
#       Unnamed: 0  Sentence_id  \
# 7817        7817  COGSKL19114
# 2993        2993   HONREQ6132
# 5512        5512  HONREQ20609
# 6313        6313   PHEREQ1496
# 1191        1191  COGRES50407
# ...          ...          ...
# 5226        5226    UAESSK828
# 5390        5390   COGEXP1832
# 860          860  PHEREQ41860
# 7603        7603  COGSSK27119
# 7270        7270  INDEDU20720
#
#                                            New_Sentence            Type
# 7817  Strong computer skills, especially  Microsoft ...           Skill
# 2993  Experience in  healthcare domain or Facets imp...     Requirement
# 5512  Experience in the  software development of sen...     Requirement
# 6313  Experience in designing  and implementing REST...     Requirement
# 1191  Continuously monitor the working environment a...  Responsibility
# ...                                                 ...             ...
# 5226  Demonstrated analytical ability and problem-so...       SoftSkill
# 5390             5+ years standard  costing experience.      Experience
# 860   Demonstrated skills developing and delivering ...     Requirement
# 7603  Excellent English verbal and written  communic...       SoftSkill
# 7270  For Philippines 34 year college degree prefera...       Education
#
# [800 rows x 4 columns]

# %%
# Preprocess test data
# Splitting each document's sentence into list of words

print(f"No. of test data documnets: {len(dev)}\n")
processed_test_data = preprocess(test["New_Sentence"].tolist())
# Out:
# No. of test data documnets: 800

# %%
# Function to calculate the final accuracy

def calculateFinalAccuracy(smoothing_param):

  # Calculate Condtional Probabilities
  exp_cond_prob_laplace, edu_cond_prob_laplace, req_cond_prob_laplace, skill_cond_prob_laplace, softskill_cond_prob_laplace, responsibility_cond_prob_laplace = calculateConditionalProbabilitiy(smoothing_param)

  # Function call to predict the class type of each document in the dev data
  predicted_label_list = predictClassTypeUsingSmoothing(processed_test_data, exp_cond_prob_laplace, edu_cond_prob_laplace, req_cond_prob_laplace, skill_cond_prob_laplace, softskill_cond_prob_laplace, responsibility_cond_prob_laplace, smoothing_param)

  # Calculate the accuracy after performing Laplace Smoothing
  print(f"Smoothing parameter (alpha) = {smoothing_param}\n")
  calculateAccuracy(predicted_label_list, test["Type"].tolist(), len(test))

# %%
# Function call to calculate final accuracy

print("Final accuracy achieved: \n")
calculateFinalAccuracy(1)
# Out:
# Final accuracy achieved:
#
# Smoothing parameter (alpha) = 1
#
# Acccuracy :  63.75 %
